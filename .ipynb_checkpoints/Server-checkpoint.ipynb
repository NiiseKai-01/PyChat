# %%
import socket

# %%
s = socket.socket(socket.AF_INET,socket.SOCK_STREAM)
s.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR,1)
s.bind(("0.0.0.0",55555))
s.listen()

# conn, add=s.accept()
# print(f"Conected to {add}")
# conn.send("Hello from server".encode())
# input("Press Enter to close Server")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 3
#       1 s = socket.socket(socket.AF_INET,socket.SOCK_STREAM)
#       2 s.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR,1)
# ----> 3 s.bind(("192.168.1.104",55555))
#       4 s.listen()
#       6 # conn, add=s.accept()
#       7 # print(f"Conected to {add}")
#       8 # conn.send("Hello from server".encode())
#       9 # input("Press Enter to close Server")
#
# OSError: [Errno 99] Cannot assign requested address

# %%
#server side
conn, add = s.accept()
while True:
        x = input("Server: ")
        conn.send(x.encode())
        y = conn.recv(1024)
        print(f"Client: {y.decode()}")
